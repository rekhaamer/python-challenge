# %%
import os
import csv
import pandas as pd

# %%
BankFile=os.path.join('budget_data_1.csv')
reader= pd.read_csv(BankFile)
reader.head()
# Out:
#      Date  Revenue
# 0  Oct-12  1154293
# 1  Nov-12   885773
# 2  Dec-12  -448704
# 3  Jan-13   563679
# 4  Feb-13   555394

# %%
totalMonths=reader['Date'].count()
print('Total Months: '+str(totalMonths))
# Out:
# Total Months: 41

# %%
totalRevenue=reader['Revenue'].sum()
print('Total Revenue: '+str(totalRevenue))
# Out:
# Total Revenue: 18971412

# %%
Prv_revenue=0
chage_lst=[]
greatest_increase=0
greatest_increase_date=""
for row in reader['Revenue']:
    print(row)
    change=int(row) - Prv_revenue
    Prv_revenue=int(row)
    chage_lst = chage_lst + [change]
    print (chage_lst)
    
    
#for row2 in reader:    
 #   if (chage_lst > greatest_increase):
  #      greatest_increase_date[0] = row['Date']
   #     greatest_increase[0] = chage_lst
# Out:
# [1154293]
# [1154293, -268520]
# [1154293, -268520, -1334477]
# [1154293, -268520, -1334477, 1012383]
# [1154293, -268520, -1334477, 1012383, -8285]
# [1154293, -268520, -1334477, 1012383, -8285, 76580]
# [1154293, -268520, -1334477, 1012383, -8285, 76580, 325421]
# [1154293, -268520, -1334477, 1012383, -8285, 76580, 325421, 146652]
# [1154293, -268520, -1334477, 1012383, -8285, 76580, 325421, 146652, -410583]
# [1154293, -268520, -1334477, 1012383, -8285, 76580, 325421, 146652, -410583, -238532]
# [1154293, -268520, -1334477, 1012383, -8285, 76580, 325421, 146652, -410583, -238532, 272340]
# [1154293, -268520, -1334477, 1012383, -8285, 76580, 325421, 146652, -410583, -238532, 272340, -602256]
# [1154293, -268520, -1334477, 1012383, -8285, 76580, 325421, 146652, -410583, -238532, 272340, -602256, 214235]
# [1154293, -268520, -1334477, 1012383, -8285, 76580, 325421, 146652, -410583, -238532, 272340, -602256, 214235, -260728]
# ...

# %%
totalavg=sum(chage_lst)/len(chage_lst)
print(totalavg)
# Out:
# 883934

# %%
with open (BankFile, newline='') as File:
    FileReader=csv.reader(File, delimiter=',')
    next(FileReader)
    countrow=0
    Prv_revenue=0
    change_lst=0
    greatest_increase=0
    greatest_increase_date=""
    for row in FileReader:
        value=int(row[1])
        Date=row[0]
        change=value - Prv_revenue
        Prv_revenue=value
        change_lst = change_lst + change
        #print(change_lst)
        countrow=countrow+1
        #if change_lst>greatest_increase:
            #greatest_increase=chage_lst
          #  greatest_increase_date=Date
    print(change_lst)
    print(countrow)
    print(greatest_increase)
    print(greatest_increase_date)
# Out:
# 883934
# 41
# 0

# %%
high=max(chage_lst)
print('Max: '+str(high))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-28-91924b8dd43e> in <module>()
# ----> 1 high=max(chage_lst)
#       2 print('Max: '+str(high))
#
# ValueError: max() arg is an empty sequence

# %%
low=min(chage_lst)
print('Min: '+str(low))

# %%
reader['Revenue'].max()
# Out:
# 1195111
